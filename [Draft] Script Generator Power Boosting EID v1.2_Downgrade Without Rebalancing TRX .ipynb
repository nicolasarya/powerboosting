# %% [markdown]
# <center><em><font face="Arial" size="6px" color="#fa0f0f">EID Delete TRX & Power Boosting Script Generator v1.2</font></em></center>
#
# <center><em><font face="Arial" size="3px"> Powered by BIGBOS Squad Sumbagut</font></em></center>
#
# <center><em>-Nicolaskun-</em></center>

# %% [markdown]
# # Prerequisite
#
# ### Tabular data (excel) which contains:
#
# 1. IP OAM NE
# 2. Cell Name (example: BGE123MT1)
# 3. Sectorcarrier Id
# 4. configuredMaxTxPower after
# 5. NodeId
# 6. configuredMaxTxPower before
# 7. GsmSectorId

# %% [markdown]
# ### 1. Import library
#
# Import pandas library (for data manipulation)

# %%
import pandas as pd

# %% [markdown]
# ### 2. Import Tabular Data
#
# Import excel file from local directory as a dataframe:
# 1. Input your local .xlsx file directory (example: D:\My Works\example.xlsx)
# 2. Input sheet name from .xlsx file
#
# df = pd.read_excel(r'<font color="#fa0f0f">your .xlsx dir file here</font>',sheet_name='<font color="#fa0f0f">sheet name</font>')

# %%
#df = pd.read_excel(r'D:\My Works\My Work\RTPO PMS\Sinau mumet\Bigbos\Power Boosting\Eid\Downgrade TRX & Rebalancing TRX\OJT Power Boosting EID Sumbagut_downgrade.xlsx',sheet_name='batch_1_test_50',header=0)
df = pd.read_excel(r'C:\Users\nicolaskun\OneDrive - PT Telekomunikasi Selular\Documents\Bigbos\Power boosting Eid\Settlement 3\Power Boosting_Set-3_EID.xlsx',sheet_name='need_downgrade',header=0)

# %% [markdown]
# ### 3. Set Index
#
# Set NodeId column as dataframe index

# %%
df_new_index = df.set_index('NodeId')

# %%
df_new_index
# Out:
#                          Unnamed: 0  \
# NodeId
# BGE169MM1-JANGGA-TURUAN         NaN
# BGE169MM1-JANGGA-TURUAN         NaN
# BGE169MM1-JANGGA-TURUAN         NaN
# BGE200MM1-AMBAR-HALIM           NaN
# BIR422MM1-KOTA-JUANG-3          NaN
# ...                             ...
# BGE177MM1-TANJUNGAN             NaN
# BGE177MM1-TANJUNGAN             NaN
# RAP942MM1-TASIK-IDAMAN          NaN
# RAP942MM1-TASIK-IDAMAN          NaN
# RAP942MM1-TASIK-IDAMAN          NaN
#
#                                                                    PO Name  \
# NodeId
# BGE169MM1-JANGGA-TURUAN  EQP #1095 EQP eNode B Power Upgrade (82 Sites)...
# BGE169MM1-JANGGA-TURUAN  EQP #1095 EQP eNode B Power Upgrade (82 Sites)...
# BGE169MM1-JANGGA-TURUAN  EQP #1095 EQP eNode B Power Upgrade (82 Sites)...
# BGE200MM1-AMBAR-HALIM    EQP #1095 EQP eNode B Power Upgrade (82 Sites)...
# BIR422MM1-KOTA-JUANG-3   EQP #1095 EQP eNode B Power Upgrade (82 Sites)...
# ...

# %%
df_new_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, BGE169MM1-JANGGA-TURUAN to RAP942MM1-TASIK-IDAMAN
# Data columns (total 31 columns):
# Unnamed: 0                  0 non-null float64
# PO Name                     170 non-null object
# PO Number                   170 non-null int64
# Start Date                  170 non-null datetime64[ns]
# Capex Name                  170 non-null object
# SOW                         170 non-null object
# Detail SoW                  170 non-null object
# Sector Impact               170 non-null object
# sector_1                    67 non-null float64
# sector_2                    57 non-null float64
# sector_3                    46 non-null float64
# Total Sector Impact         170 non-null int64
# Sub Band                    170 non-null object
# NE ID Impl                  170 non-null object
# Site ID Impl M              170 non-null object
# key_nodeid_sectorcarrier    170 non-null object
# ...

# %%
df_new_index['Sectorcarrier'] = df_new_index['Sectorcarrier'].astype(int)

# %%
df.isna().any()
# Out:
# Unnamed: 0                   True
# PO Name                     False
# PO Number                   False
# Start Date                  False
# Capex Name                  False
# SOW                         False
# Detail SoW                  False
# Sector Impact               False
# sector_1                     True
# sector_2                     True
# sector_3                     True
# Total Sector Impact         False
# Sub Band                    False
# NE ID Impl                  False
# Site ID Impl M              False
# key_nodeid_sectorcarrier    False
# key_add_site_id             False
# key_nodeid_sector           False
# NodeId                      False
# IP OAM NEW                  False
# GsmSectorId                 False
# EUtranCellFDDId             False
# before                      False
# after                       False
# Sectorcarrier               False
# sector                      False
# Site Name Impl              False
# ...

# %% [markdown]
# ### 4. Create Script Template
#
# Paste power boosting script template, separate each row with *. Check for maximum count of cell executed in each site. In this case each site have no more than 3 cell executed, so we create 3 string templates (raw_script_3, raw_script_2, raw_script_1).
#
# If there are sites which have 4 cell to be executed, create 4 string templates.

# %%
# For site which has 3 cells executed

raw_script_3 = """confb+
*
gs+
*
lt all
*
safe-
*
cvms before_power_boosting_16032022
*
lbl GsmSector=PS5572A,Trx=4
*
lbl GsmSector=PS5572A,Trx=3
*
lbl GsmSector=PS5572A,Trx=2
*
lbl GsmSector=PS5572B,Trx=4
*
lbl GsmSector=PS5572B,Trx=3
*
lbl GsmSector=PS5572B,Trx=2
*
lbl GsmSector=PS5572C,Trx=4
*
lbl GsmSector=PS5572C,Trx=3
*
lbl GsmSector=PS5572C,Trx=2
*
wait 20
*
ldel GsmSector=BE5017A,Trx=4
*
ldel GsmSector=BE5017A,Trx=3
*
ldel GsmSector=BE5017A,Trx=2
*
ldel GsmSector=BE5017B,Trx=4
*
ldel GsmSector=BE5017B,Trx=3
*
ldel GsmSector=BE5017B,Trx=2
*
ldel GsmSector=BE5017C,Trx=4
*
ldel GsmSector=BE5017C,Trx=3
*
ldel GsmSector=BE5017C,Trx=2
*
wait 20
*
lbl BGE017MT1
*
lbl BGE017MT2
*
lbl BGE017MT3
*
wait 20
*
lset sectorcarrier=7 configuredMaxTxPower 80000
*
lset sectorcarrier=8 configuredMaxTxPower 80000
*
lset sectorcarrier=9 configuredMaxTxPower 80000
*
wait 20
*
ldeb BGE017MT1
*
ldeb BGE017MT2
*
ldeb BGE017MT3
*
cvms after_power_boosting_16032022
*
confb-
*
gs-"""

# %%
# For site which has 2 cells executed

raw_script_2 = """confb+
*
gs+
*
lt all
*
safe-
*
cvms before_power_boosting_16032022
*
lbl GsmSector=PS5572A,Trx=4
*
lbl GsmSector=PS5572A,Trx=3
*
lbl GsmSector=PS5572A,Trx=2
*
lbl GsmSector=PS5572B,Trx=4
*
lbl GsmSector=PS5572B,Trx=3
*
lbl GsmSector=PS5572B,Trx=2
*
wait 20
*
ldel GsmSector=BE5017A,Trx=4
*
ldel GsmSector=BE5017A,Trx=3
*
ldel GsmSector=BE5017A,Trx=2
*
ldel GsmSector=BE5017B,Trx=4
*
ldel GsmSector=BE5017B,Trx=3
*
ldel GsmSector=BE5017B,Trx=2
*
wait 20
*
lbl BGE017MT1
*
lbl BGE017MT2
*
wait 20
*
lset sectorcarrier=7 configuredMaxTxPower 80000
*
lset sectorcarrier=8 configuredMaxTxPower 80000
*
wait 20
*
ldeb BGE017MT1
*
ldeb BGE017MT2
*
cvms after_power_boosting_16032022
*
confb-
*
gs-"""

# %%
# For site which has 1 cell executed

raw_script_1 = """confb+
*
gs+
*
lt all
*
safe-
*
cvms before_power_boosting_16032022
*
lbl GsmSector=PS5572A,Trx=4
*
lbl GsmSector=PS5572A,Trx=3
*
lbl GsmSector=PS5572A,Trx=2
*
wait 20
*
ldel GsmSector=BE5017A,Trx=4
*
ldel GsmSector=BE5017A,Trx=3
*
ldel GsmSector=BE5017A,Trx=2
*
wait 20
*
lbl BGE017MT1
*
wait 20
*
lset sectorcarrier=7 configuredMaxTxPower 80000
*
wait 20
*
ldeb BGE017MT1
*
cvms after_power_boosting_16032022
*
confb-
*
gs-"""

# %% [markdown]
# ### 5. Create Dictionary
#
# Create dictionary from script template

# %%
dict_script_3 = dict((x,y) for x,y in enumerate(raw_script_3.split()))
dict_script_2 = dict((x,y) for x,y in enumerate(raw_script_2.split()))
dict_script_1 = dict((x,y) for x,y in enumerate(raw_script_1.split()))

# %%
dict_script_3
# Out:
# {0: 'confb+',
#  1: '*',
#  2: 'gs+',
#  3: '*',
#  4: 'lt',
#  5: 'all',
#  6: '*',
#  7: 'safe-',
#  8: '*',
#  9: 'cvms',
#  10: 'before_power_boosting_16032022',
#  11: '*',
#  12: 'lbl',
#  13: 'GsmSector=PS5572A,Trx=4',
#  14: '*',
#  15: 'lbl',
#  16: 'GsmSector=PS5572A,Trx=3',
#  17: '*',
#  18: 'lbl',
#  19: 'GsmSector=PS5572A,Trx=2',
#  20: '*',
#  21: 'lbl',
#  22: 'GsmSector=PS5572B,Trx=4',
#  23: '*',
#  24: 'lbl',
#  25: 'GsmSector=PS5572B,Trx=3',
#  26: '*',
#  27: 'lbl',
#  28: 'GsmSector=PS5572B,Trx=2',
#  29: '*',
#  30: 'lbl',
#  31: 'GsmSector=PS5572C,Trx=4',
#  32: '*',
#  33: 'lbl',
#  34: 'GsmSector=PS5572C,Trx=3',
#  35: '*',
#  36: 'lbl',
#  37: 'GsmSector=PS5572C,Trx=2',
#  38: '*',
#  39: 'wait',
#  40: '20',
#  41: '*',
#  42: 'ldel',
#  43: 'GsmSector=BE5017A,Trx=4',
#  44: '*',
#  45: 'ldel',
#  46: 'GsmSector=BE5017A,Trx=3',
#  47: '*',
#  48: 'ldel',
#  49: 'GsmSector=BE5017A,Trx=2',
#  50: '*',
#  51: 'ldel',
#  52: 'GsmSector=BE5017B,Trx=4',
# ...

# %% [markdown]
# ### 6. Create Unique NodeId Variable
#
# Create list of unique NodeId, assign to nodeid_unique variable

# %%
nodeid_unique = list(df['NodeId'].unique())

# %%
len(nodeid_unique)
# Out:
# 67

# %%
nodeid_unique
# Out:
# ['BGE169MM1-JANGGA-TURUAN',
#  'BGE200MM1-AMBAR-HALIM',
#  'BIR422MM1-KOTA-JUANG-3',
#  'BKJ362MM1-LAWE-BERINGIN',
#  'CAG552MM1-KRUENG-SABE',
#  'JHO304MM1-LHONG2',
#  'KIS547MM1-SIMPANG-RGM',
#  'KPD301MM1-BONAN-DOLOK',
#  'LGS006MM1-TANJONG-KAPAI',
#  'LGS038MM1-ALUE-DUA',
#  'LHK029MM1-MUARA-DUA',
#  'LHK167MM1-BLANG-PULO',
#  'N-LHK171MM1-ALUE-PAPAN',
#  'MAK768MM1-PULO-TENGAH',
#  'PMR047MM1-JORLANG-HATARAN',
#  'PMR092MM1-DOLOK-SARIBU',
#  'PMR169MM1-HUTA-LINGGA',
#  'PMR366MM1-PELAB-AJIBATA',
#  'PMR477MM1-GIRSANG-AJIBATA',
#  'PMR968MM2-BANDAR-MASILAM',
#  'PMS219MM1-SIANTAR-MARTOBA',
#  'PMS310MM1-MEGALAND-SIANTAR',
#  'PMS323MM1-SINAR-RAYA',
#  'PSP502MM2-HASAHATAN-JULU',
#  'PSP526MM1-PADANG-BOLAK-JULU',
#  'PSP553MM1-TANJUNG-BARU',
#  'N-PYB246MM1-MUARA-BANGKO',
#  'N-PYB629MM1-SIRAMBAS',
#  'RAP122MM1-KUALA-BERINGIN',
#  'RAP259MM1-TUGU-SARI',
#  'RAP265MM1-PERMANUKAN',
#  'E_RAP760MM1_MERBAU-HUB_TEL',
#  'SBG425MM1-MERPATI-SIBOLGA',
#  'SDK102MM1-BELANG-MALUM',
# ...

# %%
list(df_new_index.loc[nodeid_unique[0]]['GsmSectorId'])[0]
# Out:
# 'BE5169A'

# %%
df_new_index.loc[nodeid_unique[1]]['GsmSectorId']
# Out:
# 'BE5200A'

# %%
df_new_index.loc[nodeid_unique[1]]
# Out:
# Unnamed: 0                                                                NaN
# PO Name                     EQP #1095 EQP eNode B Power Upgrade (82 Sites)...
# PO Number                                                          4100001549
# Start Date                                                2022-03-25 00:00:00
# Capex Name                                                  Settlement 3 2022
# SOW                                                            Power Boosting
# Detail SoW                                          EQP eNode B Power Upgrade
# Sector Impact                                                          Sector
# sector_1                                                                    1
# sector_2                                                                  NaN
# sector_3                                                                  NaN
# Total Sector Impact                                                         1
# ...

# %% [markdown]
# ### 7. Create Execute .mos Files
#
# In this case column names that have to be considered are:
# 1. EUtranCellFDDId (column name which contains cellid name, for example BGE123MT1)
# 2. Sectorcarrier (column name which contains sectorcarrier id)
# 3. after (column name which contains configuredMaxTxPower values after execution)
# 4. IP OAM Updated (column which contains IP OAM of each site)
# 5. NodeId (column which contains node name of each site)
# 6. before (column name which contains configuredMaxTxPower values before execution)
# 7. GsmSectorId (column name which contains GsmSectorId from each 2G cell)
#
# You can change your column name (excel input .xlsx) according to these column names. This column names are case sensitive.
#
# Set your local directory to save the execute script.
#
# with open(r'<font color="#fa0f0f">Your local dir here</font>'+list(df_new_index.loc[nodeid_unique[n]]['IP OAM Updated'])[0]+'.mos', 'w') as f:

# %%
def execute_del_boosting():
    for n,node in enumerate(nodeid_unique):
        if df_new_index.loc[nodeid_unique[n]].shape[0] == 3:
            dict_script_3[13] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=4'
            dict_script_3[16] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=3'
            dict_script_3[19] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=2'

            dict_script_3[22] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=4'
            dict_script_3[25] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=3'
            dict_script_3[28] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=2'

            dict_script_3[31] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=4'
            dict_script_3[34] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=3'
            dict_script_3[37] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=2'

            dict_script_3[43] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=4'
            dict_script_3[46] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=3'
            dict_script_3[49] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=2'

            dict_script_3[52] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=4'
            dict_script_3[55] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=3'
            dict_script_3[58] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=2'

            dict_script_3[61] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=4'
            dict_script_3[64] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=3'
            dict_script_3[67] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=2'

            dict_script_3[73] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[0]
            dict_script_3[76] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[1]
            dict_script_3[79] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[2]

            dict_script_3[85] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[0])
            dict_script_3[90] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[1])
            dict_script_3[95] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[2])

            dict_script_3[87] = str(list(df_new_index.loc[nodeid_unique[n]]['after'])[0])
            dict_script_3[92] = str(list(df_new_index.loc[nodeid_unique[n]]['after'])[1])
            dict_script_3[97] = str(list(df_new_index.loc[nodeid_unique[n]]['after'])[2])

            dict_script_3[103] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[0]
            dict_script_3[106] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[1]
            dict_script_3[109] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[2]

            with open(r'C:\Users\nicolaskun\OneDrive - PT Telekomunikasi Selular\Documents\Bigbos\Power boosting Eid\Settlement 3\need_downgrade\execute\\'+list(df_new_index.loc[nodeid_unique[n]]['IP OAM NEW'])[0]+'.mos', 'w') as f:
                list_script3 = list(dict_script_3.values())
                flat_script3 = " "
                flat_script3 = flat_script3.join(list_script3)
                flat_script3 = flat_script3.replace('*','\n')
                flat_script3 = flat_script3.replace(' \n ','\n')
                f.write(flat_script3)
            n+=1
        elif df_new_index.loc[nodeid_unique[n]].shape[0] == 2:
            dict_script_2[13] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=4'
            dict_script_2[16] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=3'
            dict_script_2[19] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=2'

            dict_script_2[22] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=4'
            dict_script_2[25] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=3'
            dict_script_2[28] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=2'

            dict_script_2[34] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=4'
            dict_script_2[37] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=3'
            dict_script_2[40] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=2'

            dict_script_2[43] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=4'
            dict_script_2[46] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=3'
            dict_script_2[49] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=2'

            dict_script_2[55] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[0]
            dict_script_2[58] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[1]

            dict_script_2[64] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[0])
            dict_script_2[69] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[1])

            dict_script_2[66] = str(list(df_new_index.loc[nodeid_unique[n]]['after'])[0])
            dict_script_2[71] = str(list(df_new_index.loc[nodeid_unique[n]]['after'])[1])

            dict_script_2[77] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[0]
            dict_script_2[80] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[1]

            with open(r'C:\Users\nicolaskun\OneDrive - PT Telekomunikasi Selular\Documents\Bigbos\Power boosting Eid\Settlement 3\need_downgrade\execute\\'+list(df_new_index.loc[nodeid_unique[n]]['IP OAM NEW'])[0]+'.mos', 'w') as f:
                list_script2 = list(dict_script_2.values())
                flat_script2 = " "
                flat_script2 = flat_script2.join(list_script2)
                flat_script2 = flat_script2.replace('*','\n')
                flat_script2 = flat_script2.replace(' \n ','\n')
                f.write(flat_script2)
            n+=1
        else:
            dict_script_1[13] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=4'
            dict_script_1[16] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=3'
            dict_script_1[19] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=2'

            dict_script_1[25] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=4'
            dict_script_1[28] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=3'
            dict_script_1[31] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=2'

            dict_script_1[37] = df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId']

            dict_script_1[43] = 'sectorcarrier='+str(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])

            dict_script_1[45] = str(df_new_index.loc[nodeid_unique[n]]['after'])

            dict_script_1[51] = df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId']

            with open(r'C:\Users\nicolaskun\OneDrive - PT Telekomunikasi Selular\Documents\Bigbos\Power boosting Eid\Settlement 3\need_downgrade\execute\\'+df_new_index.loc[nodeid_unique[n]]['IP OAM NEW']+'.mos', 'w') as f:
                list_script1 = list(dict_script_1.values())
                flat_script1 = " "
                flat_script1 = flat_script1.join(list_script1)
                flat_script1 = flat_script1.replace('*','\n')
                flat_script1 = flat_script1.replace(' \n ','\n')
                f.write(flat_script1)
            n+=1

# %% [markdown]
# Execute to get boosting script :)

# %%
execute_del_boosting()

# %% [markdown]
# ### 8. Create Fallback .mos Files
#
# Set your local directory to save the fallback script.
#
# with open(r'<font color="#fa0f0f">Your local dir here</font>'+list(df_new_index.loc[nodeid_unique[n]]['IP OAM Updated'])[0]+'.mos', 'w') as f:

# %%
def fallback_del_boosting():
    for n,node in enumerate(nodeid_unique):
        if df_new_index.loc[nodeid_unique[n]].shape[0] == 3:
            dict_script_3[13] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=4'
            dict_script_3[16] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=3'
            dict_script_3[19] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=2'

            dict_script_3[22] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=4'
            dict_script_3[25] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=3'
            dict_script_3[28] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=2'

            dict_script_3[31] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=4'
            dict_script_3[34] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=3'
            dict_script_3[37] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=2'

            dict_script_3[43] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=4'
            dict_script_3[46] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=3'
            dict_script_3[49] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=2'

            dict_script_3[52] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=4'
            dict_script_3[55] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=3'
            dict_script_3[58] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=2'

            dict_script_3[61] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=4'
            dict_script_3[64] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=3'
            dict_script_3[67] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[2])+',Trx=2'

            dict_script_3[73] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[0]
            dict_script_3[76] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[1]
            dict_script_3[79] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[2]

            dict_script_3[85] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[0])
            dict_script_3[90] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[1])
            dict_script_3[95] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[2])

            dict_script_3[87] = str(list(df_new_index.loc[nodeid_unique[n]]['before'])[0])
            dict_script_3[92] = str(list(df_new_index.loc[nodeid_unique[n]]['before'])[1])
            dict_script_3[97] = str(list(df_new_index.loc[nodeid_unique[n]]['before'])[2])

            dict_script_3[103] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[0]
            dict_script_3[106] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[1]
            dict_script_3[109] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[2]

            with open(r'C:\Users\nicolaskun\OneDrive - PT Telekomunikasi Selular\Documents\Bigbos\Power boosting Eid\Settlement 3\need_downgrade\fallback\\'+list(df_new_index.loc[nodeid_unique[n]]['IP OAM NEW'])[0]+'.mos', 'w') as f:
                list_script3 = list(dict_script_3.values())
                flat_script3 = " "
                flat_script3 = flat_script3.join(list_script3)
                flat_script3 = flat_script3.replace('*','\n')
                flat_script3 = flat_script3.replace(' \n ','\n')
                f.write(flat_script3)
            n+=1
        elif df_new_index.loc[nodeid_unique[n]].shape[0] == 2:
            dict_script_2[13] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=4'
            dict_script_2[16] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=3'
            dict_script_2[19] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=2'

            dict_script_2[22] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=4'
            dict_script_2[25] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=3'
            dict_script_2[28] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=2'

            dict_script_2[34] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=4'
            dict_script_2[37] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=3'
            dict_script_2[40] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[0])+',Trx=2'

            dict_script_2[43] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=4'
            dict_script_2[46] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=3'
            dict_script_2[49] = 'GsmSector='+str(list(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])[1])+',Trx=2'

            dict_script_2[55] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[0]
            dict_script_2[58] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[1]

            dict_script_2[64] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[0])
            dict_script_2[69] = 'sectorcarrier='+str(list(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])[1])

            dict_script_2[66] = str(list(df_new_index.loc[nodeid_unique[n]]['before'])[0])
            dict_script_2[71] = str(list(df_new_index.loc[nodeid_unique[n]]['before'])[1])

            dict_script_2[77] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[0]
            dict_script_2[80] = list(df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId'])[1]

            with open(r'C:\Users\nicolaskun\OneDrive - PT Telekomunikasi Selular\Documents\Bigbos\Power boosting Eid\Settlement 3\need_downgrade\fallback\\'+list(df_new_index.loc[nodeid_unique[n]]['IP OAM NEW'])[0]+'.mos', 'w') as f:
                list_script2 = list(dict_script_2.values())
                flat_script2 = " "
                flat_script2 = flat_script2.join(list_script2)
                flat_script2 = flat_script2.replace('*','\n')
                flat_script2 = flat_script2.replace(' \n ','\n')
                f.write(flat_script2)
            n+=1
        else:
            dict_script_1[13] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=4'
            dict_script_1[16] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=3'
            dict_script_1[19] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=2'

            dict_script_1[25] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=4'
            dict_script_1[28] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=3'
            dict_script_1[31] = 'GsmSector='+str(df_new_index.loc[nodeid_unique[n]]['GsmSectorId'])+',Trx=2'

            dict_script_1[37] = df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId']

            dict_script_1[43] = 'sectorcarrier='+str(df_new_index.loc[nodeid_unique[n]]['Sectorcarrier'])

            dict_script_1[45] = str(df_new_index.loc[nodeid_unique[n]]['before'])

            dict_script_1[51] = df_new_index.loc[nodeid_unique[n]]['EUtranCellFDDId']

            with open(r'C:\Users\nicolaskun\OneDrive - PT Telekomunikasi Selular\Documents\Bigbos\Power boosting Eid\Settlement 3\need_downgrade\fallback\\'+df_new_index.loc[nodeid_unique[n]]['IP OAM NEW']+'.mos', 'w') as f:
                list_script1 = list(dict_script_1.values())
                flat_script1 = " "
                flat_script1 = flat_script1.join(list_script1)
                flat_script1 = flat_script1.replace('*','\n')
                flat_script1 = flat_script1.replace(' \n ','\n')
                f.write(flat_script1)
            n+=1

# %% [markdown]
# Execute to get fallback script :)

# %%
fallback_del_boosting()
